# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# loading data
iris = load_iris()
X = iris.data[:, 3].reshape(-1, 1) # petal width
y = iris.data[:, 2].reshape(-1, 1) # petal length

# %%
# model
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
# predicting
y_pred = regressor.predict(X)

# %%
# metrices
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Square Error:", rmse)
print("R-squared value:", r2)
# Out:
# Mean Absolute Error: 0.36579694412763775
# Mean Squared Error: 0.22563168777869236
# Root Mean Square Error: 0.47500703971487873
# R-squared value: 0.9271098389904927

# %%
# plots
fig, ax = plt.subplots(figsize = (15,10))

plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title('Petal width vs petal length')
plt.xlabel('Petal width')
plt.ylabel('Petal length')
plt.show()
